# %%
"""
author: Jaisanker
"""
"""
DocString:   
            The Game is a football championship simulation that lets you choose your teams 
            and play preliminary league games. If you are among placed in the top 4 among 
            the 8 teams, you will progress into the semi finals which is a knock out round. 
            If your team wins, you can progress into the finals and win.Winning/loosing is 
            determined by the randomly assigned team ranking attribute of the class team.
    
    Story : The prestigious Super 8 Championships is gonna be played among the Top 8 Teams 
            as per the FIFA ranking at the time of declaration of the championship towards 
            from September, 2019. The finalists of the championship get to directly play 
            2022 Qatar Qorld cup Group Stages.
    
    Known Bugs : The outer most while loop throws an error if the entered valu is " " or space
    
"""
import random
import time
import sys

#-----------------------Class Definitions & Initiation------------------------

class team:
    team_no = ""
    team_name = ""
    coach_name = ""
    player_name = ['']
    player_goals = ['']
    playing_XI = ['']
    team_ranking = 0
    prelim_point = 0
    charity = 0
    
prelim_teams = []
for i in range(0,8):
    prelim_teams.append(team())

prelim_teams_sorted = []
for i in range(0,8):
    prelim_teams_sorted.append(team())
    
semi_finals_teams = []
for i in range(0,4):
    semi_finals_teams.append(team())
    
final_teams = []
for i in range(0,2):
    final_teams.append(team())
    
prelim_teams[0].team_no = 1
prelim_teams[0].team_ranking = random.sample(range(1, 100), 1)
prelim_teams[0].team_name    = 'Belgium'
prelim_teams[0].coach_name   = 'Roberto Martínez'
prelim_teams[0].player_name  =  [ 'Thibaut Courtois','Toby Alderweireld',
                                  'Thomas Vermaelen','Vincent Kompany','Jan Vertonghen',
                                  'Axel Witsel','Kevin De Bruyne','Marouane Fellaini',
                                  'Romelu Lukaku','Eden Hazard','Yannick Carrasco']

prelim_teams[0].player_goals = [0,3,1,4,8,9,14,17,36,22,5,0,0,14,5,1,0,0,5,0,7,5,0]

prelim_teams[1].team_no = 2
prelim_teams[1].team_ranking = random.sample(range(1, 100), 1)
prelim_teams[1].team_name =  'France'
prelim_teams[1].coach_name = 'Didier Deschamps'
prelim_teams[1].player_name  = [   'Hugo Lloris','Benjamin Pavard',
                                   'Presnel Kimpembe','Raphaël Varane','Samuel Umtiti',
                                   'Paul Pogba','Antoine Griezmann','Thomas Lemar',
                                   'Olivier Giroud','Kylian Mbappé','Ousmane Dembélé']
prelim_teams[1].player_goals = [0,0,0,2,2,9,20,3,31,4,2,0,1,9,0,0,1,2,1,0,0,0,0]

prelim_teams[2].team_no = 3
prelim_teams[2].team_ranking = random.sample(range(1, 100), 1)
prelim_teams[2].team_name =  'Brazil'
prelim_teams[2].coach_name = 'Adenor Leonardo Bacchi'
prelim_teams[2].player_name = [     'Alisson','Thiago Silva',
                                    'Miranda','Pedro Geromel','Casemiro',
                                    'Filipe Luís','Douglas Costa','Renato Augusto',
                                    'Gabriel Jesus','Neymar','Philippe Coutinho']
prelim_teams[2].player_goals = [0,5,2,0,0,2,3,5,10,55,10,6,0,0,12,0,2,0,8,6,1,0,0]

prelim_teams[3].team_no = 4
prelim_teams[3].team_ranking = random.sample(range(1, 100), 1)
prelim_teams[3].team_name =  'England'
prelim_teams[3].coach_name = 'Gareth Southgate'
prelim_teams[3].player_name = [     'Jordan Pickford','Kyle Walker',
                                    'Danny Rose','Eric Dier','John Stones',
                                    'Harry Maguire','Jesse Lingard','Jordan Henderson',
                                    'Harry Kane','Raheem Sterling','Jamie Vardy']
prelim_teams[3].player_goals = [0,0,0,3,0,0,1,0,13,2,7,0,0,16,5,0,0,7,3,2,0,0,0]

prelim_teams[4].team_no = 5
prelim_teams[4].team_ranking = random.sample(range(1, 100), 1)
prelim_teams[4].team_name =  'Portugal'
prelim_teams[4].coach_name = 'Fernando Santos'
prelim_teams[4].player_name = [ 'Rui Patrício','Bruno Alves',
                                'Pepe','Manuel Fernandes','Raphaël Guerreiro',
                                'José Fonte','Cristiano Ronaldo','João Moutinho',
                                'André Silva','João Mário','Bernardo Silva']
prelim_teams[4].player_goals = [0,11,5,3,2,0,81,7,12,2,2,0,0,2,0,1,3,0,0,9,1,0,1]

prelim_teams[5].team_no = 6
prelim_teams[5].team_ranking = random.sample(range(1, 100), 1)
prelim_teams[5].team_name =  'Uruguay'
prelim_teams[5].coach_name = 'Óscar Tabárez'
prelim_teams[5].player_name = [ 'Fernando Muslera','José Giménez',
                                'Diego Godín','Guillermo Varela','Carlos Sánchez',
                                'Rodrigo Bentancur','Cristian Rodríguez','Nahitan Nández',
                                'Luis Suárez','Giorgian De Arrascaeta','Cristhian Stuani']
prelim_teams[5].player_goals = [0,5,8,0,1,0,11,0,51,2,5,0,0,0,1,3,0,0,1,0,42,4,0]

prelim_teams[6].team_no = 7
prelim_teams[6].team_ranking = random.sample(range(1, 100), 1)
prelim_teams[6].team_name =   'Spain'
prelim_teams[6].coach_name  = 'Fernando Hierro'
prelim_teams[6].player_name = [ 'David de Gea','Dani Carvajal',
                                'Gerard Piqué','Nacho','Sergio Busquets',
                                'Andrés Iniesta','Saúl','Koke',
                                'Rodrigo','Thiago','Lucas Vázquez']
prelim_teams[6].player_goals = [0,0,5,0,2,14,0,0,2,2,0,1,0,0,13,1,5,8,7,0,35,10,0]

prelim_teams[7].team_no = 8
prelim_teams[7].team_ranking = random.sample(range(1, 100), 1)
prelim_teams[7].team_name =  'Croatia'
prelim_teams[7].coach_name = 'Zlatko Dalić'
prelim_teams[7].player_name = [ 'Dominik Livaković','Šime Vrsaljko',
                                'Ivan Strinić','Ivan Perišić','Vedran Ćorluka',
                                'Dejan Lovren','Ivan Rakitić','Mateo Kovačić',
                                'Andrej Kramarić','Luka Modrić','Marcelo Brozović']
prelim_teams[7].player_goals = [0,0,0,18,4,2,14,1,9,12,6,0,0,0,0,15,30,1,1,1,2,0,0]

#----------------------------------Functions----------------------------------

def prelim_fn(element=team()):
    """Compares the ranking of the chosen team against others and calculates total points scored based on the number of
       wins, draws or losses"""
    for i in range(0,8):
        if(element.team_ranking>prelim_teams[i].team_ranking):
            element.prelim_point+=2
            print("\nHURRAAYYYY...You won the game... WELL DONE.")
            time.sleep(1)
        elif(element.team_ranking<prelim_teams[i].team_ranking):
            print("\nOOPS...You lost the game... BETTER LUCK NEXT TIME.")
            time.sleep(1)
        elif(element.team_ranking==prelim_teams[i].team_ranking):
            if(element.team_name == prelim_teams[i].team_name):
                element.prelim_point +=1
            elif(element.team_ranking==prelim_teams[i].team_ranking) and (element.team_name != prelim_teams[i].team_name):
                element.prelim_point +=1
                print("\nHMMMM...The game was drawn... NOT BAD.")
                time.sleep(1)
            else:
                element.prelim_point +=1  
    return element.prelim_point - 1

# Returning value - 1 to account for the step where team compares with itself
# and adds one point to the prelim_point

def dummy_prelim_fn(element=team()):
    """Similar to prelim_fn to populate points for the rest of seven teams """
    for i in range(0,8):
        if(element.team_ranking>prelim_teams[i].team_ranking):
            element.prelim_point+=2
        elif(element.team_ranking<prelim_teams[i].team_ranking):
            element.prelim_point = element.prelim_point
        elif(element.team_ranking==prelim_teams[i].team_ranking):
            element.prelim_point+=1
        
    return element.prelim_point - 1
# Returning value - 1 to account for the step where team compares with itself
# and adds one point to the prelim_point

def yes_or_no(question):
    """function to accept yes or no from the user to determine whether he wants to continue playing or not"""
    reply = str(input(question+' (y/n): ')).lower().strip()
    if reply[0] == 'n':
        print (" \nBye bye.\nHave a good day.\nSee you back here soon...")
        return 1
    elif reply[0] == 'y':
        return 0
    else:
        return yes_or_no("Please Enter (Y/N) ")
input_names = ['Belgium','France','Brazil','England','Portugal','Uruguay','Spain','Croatia']
input_names_upper = ['BELGIUM','FRANCE','BRAZIL','ENGLAND','PORTUGAL','URUGUAY','SPAIN','CROATIA']
input_names_lower = ['belgium','belgium','brazil','england','portugal','uruguay','spain','croatia']
input_nos = ['1','2','3','4','5','6','7','8']
#--------------------------------Main Program---------------------------------

while True:
    print(f"""\n\n --------------------------------THE WORLD SUPER 8 CHAMPIONSHIP--------------------------------
              \n\n Welcome to The World Super 8 Championship. 
                \n This championship is between the top 8 teams in the FIFA Ranking
                \n The finalists get to enter the group stages of 
                \n 2022 WORLD CUP, QATAR 
                \n without toiling through the gruelling qualifiers.\n""")
    print(f"""\n\t\t\t\t Select your Team
              \t\t\t -----------------""")
    print("\t\t\t\t 1. ",prelim_teams[0].team_name)
    time.sleep(1)
    print("\t\t\t\t 2. ",prelim_teams[1].team_name)
    time.sleep(1)
    print("\t\t\t\t 3. ",prelim_teams[2].team_name)
    time.sleep(1)
    print("\t\t\t\t 4. ",prelim_teams[3].team_name)  
    time.sleep(1)
    print("\t\t\t\t 5. ",prelim_teams[4].team_name)  
    time.sleep(1)
    print("\t\t\t\t 6. ",prelim_teams[5].team_name)  
    time.sleep(1)
    print("\t\t\t\t 7. ",prelim_teams[6].team_name)
    time.sleep(1)
    print("\t\t\t\t 8. ",prelim_teams[7].team_name)
    time.sleep(1)
                    
    
    while True:
        try:
            team_id = input("\nPlease select your team : ")
            if team_id in input_names:
                print("Great...Let's Start...")
                break
            
            elif team_id in input_names_upper:
                print("Great...Let's Start...")
                break
            
            elif team_id in input_names_lower:
                print("Great...Let's Start...")
                break
                
            elif team_id in input_nos:
                print("Great...Let's Start...")
                break
                
            else:
                print("Oops! Value out of range!!! Please try again...")
                
        except:
                print("Oops! Not a valid choice!!! Please try again ...")
                
    print("\n----------------------------------PRELIMINARY ROUND----------------------------------\n")
    choice_team = team()
    choice_team.team_no = team_id
    
    prelim_teams[0].prelim_point = 0
    prelim_teams[1].prelim_point = 0
    prelim_teams[2].prelim_point = 0
    prelim_teams[3].prelim_point = 0
    prelim_teams[4].prelim_point = 0
    prelim_teams[5].prelim_point = 0
    prelim_teams[6].prelim_point = 0
    prelim_teams[7].prelim_point = 0
    
    if team_id == 1 or team_id == '1' or team_id == 'Belgium' or team_id == 'belgium' or team_id == 'BELGIUM':
        choice_team = prelim_teams[0]
        print("\nYou Chose\t:", prelim_teams[0].team_name,"\nCoach\t\t:",prelim_teams[0].coach_name)
        print("\nYour Playing XI : ")
        for i in range (0,11):
            print("\t\t",prelim_teams[0].player_name[i])

        prelim_teams[1].prelim_point = dummy_prelim_fn(prelim_teams[1])
        prelim_teams[2].prelim_point = dummy_prelim_fn(prelim_teams[2])
        prelim_teams[3].prelim_point = dummy_prelim_fn(prelim_teams[3])
        prelim_teams[4].prelim_point = dummy_prelim_fn(prelim_teams[4])
        prelim_teams[5].prelim_point = dummy_prelim_fn(prelim_teams[5])
        prelim_teams[6].prelim_point = dummy_prelim_fn(prelim_teams[6])
        prelim_teams[7].prelim_point = dummy_prelim_fn(prelim_teams[7])
        prelim_teams[0].prelim_point = prelim_fn(prelim_teams[0])

    elif team_id == 2 or team_id == '2' or team_id == 'France' or team_id == 'france' or team_id == 'FRANCE':
        choice_team = prelim_teams[1]
        print("\nYou Chose\t:", prelim_teams[1].team_name,"\nCoach\t\t:",prelim_teams[1].coach_name)
        print("\nYour Playing XI : ")
        for i in range (0,11):
            print("\t\t",prelim_teams[1].player_name[i])

        prelim_teams[0].prelim_point = dummy_prelim_fn(prelim_teams[0])
        prelim_teams[2].prelim_point = dummy_prelim_fn(prelim_teams[2])
        prelim_teams[3].prelim_point = dummy_prelim_fn(prelim_teams[3])
        prelim_teams[4].prelim_point = dummy_prelim_fn(prelim_teams[4])
        prelim_teams[5].prelim_point = dummy_prelim_fn(prelim_teams[5])
        prelim_teams[6].prelim_point = dummy_prelim_fn(prelim_teams[6])
        prelim_teams[7].prelim_point = dummy_prelim_fn(prelim_teams[7])
        prelim_teams[1].prelim_point = prelim_fn(prelim_teams[1])

    elif team_id == 3 or team_id == '3' or team_id == 'Brazil' or team_id == 'brazil' or team_id == 'BRAZIL':
        choice_team = prelim_teams[2]
        print("\nYou Chose\t:", prelim_teams[2].team_name,"\nCoach\t\t:",prelim_teams[2].coach_name)
        print("\nYour Playing XI : ")
        for i in range (0,11):
            print("\t\t",prelim_teams[2].player_name[i])

        prelim_teams[0].prelim_point = dummy_prelim_fn(prelim_teams[0])
        prelim_teams[1].prelim_point = dummy_prelim_fn(prelim_teams[1])
        prelim_teams[3].prelim_point = dummy_prelim_fn(prelim_teams[3])
        prelim_teams[4].prelim_point = dummy_prelim_fn(prelim_teams[4])
        prelim_teams[5].prelim_point = dummy_prelim_fn(prelim_teams[5])
        prelim_teams[6].prelim_point = dummy_prelim_fn(prelim_teams[6])
        prelim_teams[7].prelim_point = dummy_prelim_fn(prelim_teams[7])
        prelim_teams[2].prelim_point = prelim_fn(prelim_teams[2])

    elif team_id == 4 or team_id == '4' or team_id == 'England' or team_id == 'england' or team_id == 'ENGLAND':
        choice_team = prelim_teams[3]
        print("\nYou Chose\t:", prelim_teams[3].team_name,"\nCoach\t\t:",prelim_teams[3].coach_name)
        print("\nYour Playing XI : ")
        for i in range (0,11):
            print("\t\t",prelim_teams[3].player_name[i])

        prelim_teams[0].prelim_point = dummy_prelim_fn(prelim_teams[0])
        prelim_teams[1].prelim_point = dummy_prelim_fn(prelim_teams[1])
        prelim_teams[2].prelim_point = dummy_prelim_fn(prelim_teams[2])
        prelim_teams[4].prelim_point = dummy_prelim_fn(prelim_teams[4])
        prelim_teams[5].prelim_point = dummy_prelim_fn(prelim_teams[5])
        prelim_teams[6].prelim_point = dummy_prelim_fn(prelim_teams[6])
        prelim_teams[7].prelim_point = dummy_prelim_fn(prelim_teams[7])
        prelim_teams[3].prelim_point = prelim_fn(prelim_teams[3])

    elif team_id == 5 or team_id == '5' or team_id == 'Portugal' or team_id == 'portugal' or team_id == 'PORTUGAL':
        choice_team = prelim_teams[4]
        print("\nYou Chose\t:", prelim_teams[4].team_name,"\nCoach\t\t:",prelim_teams[4].coach_name)
        print("\nYour Playing XI : ")
        for i in range (0,11):
            print("\t\t",prelim_teams[4].player_name[i])

        prelim_teams[0].prelim_point = dummy_prelim_fn(prelim_teams[0])
        prelim_teams[1].prelim_point = dummy_prelim_fn(prelim_teams[1])
        prelim_teams[2].prelim_point = dummy_prelim_fn(prelim_teams[2])
        prelim_teams[3].prelim_point = dummy_prelim_fn(prelim_teams[3])
        prelim_teams[5].prelim_point = dummy_prelim_fn(prelim_teams[5])
        prelim_teams[6].prelim_point = dummy_prelim_fn(prelim_teams[6])
        prelim_teams[7].prelim_point = dummy_prelim_fn(prelim_teams[7])
        prelim_teams[4].prelim_point = prelim_fn(prelim_teams[4])

    elif team_id == 6 or team_id == '6' or team_id == 'Uruguay' or team_id == 'uruguay' or team_id == 'URUGUAY':
        choice_team = prelim_teams[5]
        print("\nYou Chose\t:", prelim_teams[5].team_name,"\nCoach\t\t:",prelim_teams[5].coach_name)
        print("\nYour Playing XI : ")
        for i in range (0,11):
            print("\t\t",prelim_teams[5].player_name[i])

        prelim_teams[0].prelim_point = dummy_prelim_fn(prelim_teams[0])
        prelim_teams[1].prelim_point = dummy_prelim_fn(prelim_teams[1])
        prelim_teams[2].prelim_point = dummy_prelim_fn(prelim_teams[2])
        prelim_teams[3].prelim_point = dummy_prelim_fn(prelim_teams[3])
        prelim_teams[4].prelim_point = dummy_prelim_fn(prelim_teams[4])
        prelim_teams[6].prelim_point = dummy_prelim_fn(prelim_teams[6])
        prelim_teams[7].prelim_point = dummy_prelim_fn(prelim_teams[7])
        prelim_teams[5].prelim_point = prelim_fn(prelim_teams[5])

    elif team_id == 7 or team_id == '7' or team_id == 'Spain' or team_id == 'spain' or team_id == 'SPAIN':
        choice_team = prelim_teams[6]
        print("\nYou Chose\t:", prelim_teams[6].team_name,"\nCoach\t\t:",prelim_teams[6].coach_name)
        print("\nYour Playing XI : ")
        for i in range (0,11):
            print("\t\t",prelim_teams[6].player_name[i])

        prelim_teams[0].prelim_point = dummy_prelim_fn(prelim_teams[0])
        prelim_teams[1].prelim_point = dummy_prelim_fn(prelim_teams[1])
        prelim_teams[2].prelim_point = dummy_prelim_fn(prelim_teams[2])
        prelim_teams[3].prelim_point = dummy_prelim_fn(prelim_teams[3])
        prelim_teams[4].prelim_point = dummy_prelim_fn(prelim_teams[4])
        prelim_teams[5].prelim_point = dummy_prelim_fn(prelim_teams[5])
        prelim_teams[7].prelim_point = dummy_prelim_fn(prelim_teams[7])
        prelim_teams[6].prelim_point = prelim_fn(prelim_teams[6])

    elif team_id == 8 or team_id == '8' or team_id == 'Croatia' or team_id == 'croatia' or team_id == 'CROATIA':
        choice_team = prelim_teams[7]
        print("\nYou Chose\t:", prelim_teams[7].team_name,"\nCoach\t\t:",prelim_teams[7].coach_name)
        print("\nYour Playing XI : ")
        for i in range (0,11):
            print("\t\t",prelim_teams[7].player_name[i])

        prelim_teams[0].prelim_point = dummy_prelim_fn(prelim_teams[0])
        prelim_teams[1].prelim_point = dummy_prelim_fn(prelim_teams[1])
        prelim_teams[2].prelim_point = dummy_prelim_fn(prelim_teams[2])
        prelim_teams[3].prelim_point = dummy_prelim_fn(prelim_teams[3])
        prelim_teams[4].prelim_point = dummy_prelim_fn(prelim_teams[4])
        prelim_teams[5].prelim_point = dummy_prelim_fn(prelim_teams[5])
        prelim_teams[6].prelim_point = dummy_prelim_fn(prelim_teams[6])
        prelim_teams[7].prelim_point = prelim_fn(prelim_teams[7])

    else:
        print("\n\n\nOoops...Something went wrong\n")
        sys.exit(0)

    prelim_teams_sorted=sorted(prelim_teams, key=lambda team:team.prelim_point)
    print(f"""\n\nWonderful. \n\nNow that we have completed the Preliminary round of the Super 8 Championship,lets look at your performance""")
    input("Press any key to continue : ")
    print(f"""\n\t\t\t\t Preliminary Stage Points Table
                           \t ------------------------------""")
    
    i=8
    for i in range(0,8):
        print("\t\t\t\t",prelim_teams_sorted[i].team_name," \t: ",prelim_teams_sorted[i].prelim_point)
        time.sleep(1)
    print("\nYou scored",choice_team.prelim_point,"points in preliminary stage\n")
    
    semi_finals_teams = prelim_teams_sorted[4:8]

    fail = 0
    pas = 0
    for i in range(0,4):
        if choice_team.team_no!= semi_finals_teams[i].team_no:
            fail +=1

        elif choice_team.team_no == semi_finals_teams[i].team_no:
            pas +=1    
        else:
            print("oops : Prelim Round")

    if pas == 0:
        print(f"""\n{choice_team.team_name} did not qualify for the semifinals. Better luck next time!!!""")
        
    elif pas > 0: 
        print(f"""\nYour team {choice_team.team_name} qualified for the semifinals. Congrats...""")
        input("\nPress any key to continue : ")
        print("\n\n.... YEYYYY....YEYYY....YEYYY....")
        time.sleep(1)
        print(f"""\n\n----------------------------------------SEMI-FINALS----------------------------------------\n
                  \n\t\t\t\t\tSemifinal List
                           \t ------------------------------""")
        i=0
        while i<4:
            print("\t\t\t\t\t",semi_finals_teams[i].team_name)
            time.sleep(1)
            i += 1
        input("\n\nPress any key to play : ")    
        pos = 0
        pas1 = 0
        fail1 = 0
        for i in range(0,4):
            semi_finals_teams[i].team_ranking = random.sample(range(1, 100), 1)
            if semi_finals_teams[i].team_name == choice_team.team_name :
                pos = i
                pas1 +=1
            else:
                fail1 +=1

        if semi_finals_teams[0].team_ranking > semi_finals_teams[2].team_ranking:
            final_teams[0] = semi_finals_teams[0]

        elif semi_finals_teams[0].team_ranking < semi_finals_teams[2].team_ranking:
            final_teams[0] = semi_finals_teams[2]
        else: 
            print("\n\tOops: Something went wrong")

        if semi_finals_teams[1].team_ranking > semi_finals_teams[3].team_ranking:
            final_teams[1] = semi_finals_teams[1]
        elif semi_finals_teams[1].team_ranking < semi_finals_teams[3].team_ranking:
            final_teams[1] = semi_finals_teams[3]
        else: 
            print("\n\t Oops: Something went wrong")

        if final_teams[0].team_no == choice_team.team_no or final_teams[1].team_no == choice_team.team_no:
            final_teams[0].team_ranking = random.sample(range(1, 100), 1)
            final_teams[1].team_ranking = random.sample(range(1, 100), 1)
            time.sleep(2)
            print(f"""\n\n\n{choice_team.team_name} reached the finals... HURAAAAYYYYYYY....""")
            input("\n\nPress any key to continue : ")
            print(f"""\n\nAre you ready for the final game? You are just one win away from being on top of the world")
                      \n\n----------------------------------FINALS ----------------------------------\n
                      \n\n\t\t{final_teams[0].team_name}\tVS\t{final_teams[1].team_name}""")
            input("\n\nPress any key to play : ")

            if final_teams[0].team_ranking > final_teams[1].team_ranking:
                if final_teams[0].team_name == choice_team.team_name:
                    print(f"""\n\n YAAYYYYYYYYYY.... {final_teams[0].team_name} won the world championship.
                              \n\n nMust be feeling good to be on top of the world. Am I Right folks???
                              \n\n And as a bonus you enter the group stage in 2022 WORLD CUP to be held in QATAR """)
                else:
                    print(f"""\n\n You Lost in the finals..
                              \n\n Man... That was close...
                              \n\n Well played team... Being No.2 in the world is not a small thing.
                              \n\n And as a bonus you enter the group stage in 2022 WORLD CUP to be held in QATAR """)

            elif final_teams[0].team_ranking < final_teams[1].team_ranking:
                if final_teams[1].team_name == choice_team.team_name:
                    print(f"""\n\n YAAYYYYYYYYYY.... {final_teams[1].team_name} won the world championship.
                              \n\n Must be feeling good to be on top of the world. Am I Right folks???
                              \n\n And as a bonus you enter the group stage in 2022 WORLD CUP to be held in QATAR """)
                else:
                    print(f"""\n\n You Lost in the finals..
                              \n\n Man... That was close...
                              \n\n Well played team... Being No.2 in the world is not a small thing.
                              \n\n And as a bonus you enter the group stage in 2022 WORLD CUP to be held in QATAR """)

            elif final_teams[0].team_ranking == final_teams[1].team_ranking:
                    print(f"""\n\n{final_teams[0].team_name} & {final_teams[1].team_name} together have won the world championship
                              \n\n And as a bonus you enter the group stage in 2022 WORLD CUP to be held in QATAR """)
            else:
                    print(f"""\n\n You Lost in the finals..
                              \n\n Man... That was close...
                              \n\n Well played team... Being No.2 in the world is not a small thing.
                              \n\n And as a bonus you enter the group stage in 2022 WORLD CUP to be held in QATAR """)

        elif final_teams[0].team_no != choice_team.team_no or final_teams[1].team_no != choice_team.team_no:
            print("Sorry... You lost & did not qualify for the finals... Better luck next time")
        else: 
            print("Oops :  Something went wrong")
            
    if(yes_or_no('\n\nDo you want to continue')):
        break
        
# Improvements

# 1) Write a function to display playing eleven row wise

# 2) Include option to select playing eleven

# 3) Write down assumptions
#    build a narrative 
# 4) include docstrings in functions

#
# Out:
#  --------------------------------THE WORLD SUPER 8 CHAMPIONSHIP--------------------------------
#
#
#  Welcome to The World Super 8 Championship.
#
#  This championship is between the top 8 teams in the FIFA Ranking
#
#  The finalists get to enter the group stages of
#
#  2022 WORLD CUP, QATAR
#
#  without toiling through the gruelling qualifiers.
#
#
# 				 Select your Team
#               			 -----------------
# 				 1.  Belgium
# 				 2.  France
# 				 3.  Brazil
# 				 4.  England
# 				 5.  Portugal
# 				 6.  Uruguay
# 				 7.  Spain
# 				 8.  Croatia
#
# Please select your team : 4
# Great...Let's Start...
#
# ----------------------------------PRELIMINARY ROUND----------------------------------
#
#
# You Chose	: England
# Coach		: Gareth Southgate
#
# Your Playing XI :
# 		 Jordan Pickford
# 		 Kyle Walker
# 		 Danny Rose
# 		 Eric Dier
# 		 John Stones
# 		 Harry Maguire
# 		 Jesse Lingard
# 		 Jordan Henderson
# 		 Harry Kane
# 		 Raheem Sterling
# 		 Jamie Vardy
#
# ...
