# %%
import pandas            as pd
import matplotlib.pyplot as plt
import seaborn           as sns


file = '01_WDIW Dataset.xlsx'
wdi = pd.read_excel(file)

ch = wdi[wdi['Cool Name'] == 'Cliffhanger']
ch.to_excel('Cliffhanger_data.xlsx')

file  = 'Cliffhanger_data.xlsx'
ch    = pd.read_excel(file)

# ----Dropping - No data for any column------------

ch_dropped=ch.drop(["Births attended by skilled health staff (% of total)"], axis=1)
ch_dropped=ch_dropped.drop(["Educational attainment, Doctoral or equivalent, population 25+, total (%) (cumulative)"], axis=1)
ch_dropped=ch_dropped.drop(["Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)"], axis=1)
ch_dropped=ch_dropped.drop(["Educational attainment, at least Master's or equivalent, population 25+, total (%) (cumulative)"], axis=1)
ch_dropped=ch_dropped.drop(["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"], axis=1)
ch_dropped=ch_dropped.drop(["Educational attainment, at least completed post-secondary, population 25+, total (%) (cumulative)"], axis=1)
ch_dropped=ch_dropped.drop(["Educational attainment, at least completed primary, population 25+ years, total (%) (cumulative)"], axis=1)
ch_dropped=ch_dropped.drop(["Educational attainment, at least completed short-cycle tertiary, population 25+, total (%) (cumulative)"], axis=1)
ch_dropped=ch_dropped.drop(["Educational attainment, at least completed upper secondary, population 25+, total (%) (cumulative)"], axis=1)
ch_dropped=ch_dropped.drop(["Income share held by fourth 20%"], axis=1)
ch_dropped=ch_dropped.drop(["Income share held by highest 20%"], axis=1)
ch_dropped=ch_dropped.drop(["Income share held by lowest 20%"], axis=1)
ch_dropped=ch_dropped.drop(["Income share held by second 20%"], axis=1)
ch_dropped=ch_dropped.drop(["Income share held by third 20%"], axis=1)
ch_dropped=ch_dropped.drop(["Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)"], axis=1)
ch_dropped=ch_dropped.drop(["Poverty headcount ratio at $3.20 a day (2011 PPP) (% of population)"], axis=1)
ch_dropped=ch_dropped.drop(["Poverty headcount ratio at national poverty lines (% of population)"], axis=1)
ch_dropped=ch_dropped.drop(["Prevalence of underweight, weight for age (% of children under 5)"], axis=1)


# ch_dropped=ch_dropped.drop(["Literacy rate, adult total (% of people ages 15 and above)"], axis=1)
# ch_dropped=ch_dropped.drop(["Literacy rate, youth total (% of people ages 15-24)"], axis=1)

#----------------------------Filling missing values---------------------------

ch_missing = ch_dropped
ch_dropped.to_excel('Cliffhanger_data_dropped.xlsx')

ch_missing.loc[9,"Access to electricity, rural (% of rural population)"] = 99.6

ch_missing.loc[0,"Age dependency ratio (% of working-age population)"]  = 42.7
ch_missing.loc[6,"Age dependency ratio (% of working-age population)"]  = 70
ch_missing.loc[8,"Age dependency ratio (% of working-age population)"]  = 42.1
ch_missing.loc[9,"Age dependency ratio (% of working-age population)"]  = 53.1
ch_missing.loc[12,"Age dependency ratio (% of working-age population)"] = 39
ch_missing.loc[17,"Age dependency ratio (% of working-age population)"] = 56.1

ch_missing.loc[0,"Age dependency ratio, old (% of working-age population)"]  = 6.7
ch_missing.loc[6,"Age dependency ratio, old (% of working-age population)"]  = 5.1
ch_missing.loc[8,"Age dependency ratio, old (% of working-age population)"]  = 5.1
ch_missing.loc[9,"Age dependency ratio, old (% of working-age population)"]  = 2.5
ch_missing.loc[12,"Age dependency ratio, old (% of working-age population)"] = 29.9
ch_missing.loc[17,"Age dependency ratio, old (% of working-age population)"] = 10.23

ch_missing.loc[0,"Age dependency ratio, young (% of working-age population)"]   = 36
ch_missing.loc[6,"Age dependency ratio, young (% of working-age population)"]   = 64.9
ch_missing.loc[8,"Age dependency ratio, young (% of working-age population)"]   = 36.9
ch_missing.loc[9,"Age dependency ratio, young (% of working-age population)"]   = 50.6
ch_missing.loc[12,"Age dependency ratio, young (% of working-age population)"]  = 9
ch_missing.loc[17,"Age dependency ratio, young (% of working-age population)"]  = 47.8

ch_missing.loc[1,"Birth rate, crude (per 1,000 people)"]  = 12.4
ch_missing.loc[10,"Birth rate, crude (per 1,000 people)"] = 14.5
ch_missing.loc[12,"Birth rate, crude (per 1,000 people)"] = 12.4
ch_missing.loc[6,"Birth rate, crude (per 1,000 people)"]  = 23.73
ch_missing.loc[8,"Birth rate, crude (per 1,000 people)"]  = 17.75
ch_missing.loc[9,"Birth rate, crude (per 1,000 people)"]  = 22.94
ch_missing.loc[17,"Birth rate, crude (per 1,000 people)"] = 19.22

ch_missing.loc[0,"Death rate, crude (per 1,000 people)"]  = 3.36
ch_missing.loc[6,"Death rate, crude (per 1,000 people)"]  = 3.57
ch_missing.loc[8,"Death rate, crude (per 1,000 people)"]  = 2.82
ch_missing.loc[9,"Death rate, crude (per 1,000 people)"]  = 5.04
ch_missing.loc[17,"Death rate, crude (per 1,000 people)"] = 7.61

ch_missing.loc[3,"GDP (current US$)"]  = 5418000000
ch_missing.loc[10,"GDP (current US$)"] = 11110000000

ch_missing.loc[3,"GDP growth (annual %)"]  = -3.473606497
ch_missing.loc[10,"GDP growth (annual %)"] = 2

ch_missing.loc[0,"Literacy rate, youth total (% of people ages 15 and above)"]  = 97.5
ch_missing.loc[2,"Literacy rate, youth total (% of people ages 15 and above)"]  = 99.082
ch_missing.loc[4,"Literacy rate, youth total (% of people ages 15 and above)"]  = 99.369
ch_missing.loc[10,"Literacy rate, youth total (% of people ages 15 and above)"] = 97.8
ch_missing.loc[11,"Literacy rate, youth total (% of people ages 15 and above)"] = 99
ch_missing.loc[12,"Literacy rate, youth total (% of people ages 15 and above)"] = 96.5
ch_missing.loc[13,"Literacy rate, youth total (% of people ages 15 and above)"] = 61.6
ch_missing.loc[14,"Literacy rate, youth total (% of people ages 15 and above)"] = 99.096
ch_missing.loc[16,"Literacy rate, youth total (% of people ages 15 and above)"] = 99.4
ch_missing.loc[18,"Literacy rate, youth total (% of people ages 15 and above)"] = 87.5

ch_missing.loc[0,"Literacy rate, youth total (% of people ages 15-24)"]  = 97.6
ch_missing.loc[2,"Literacy rate, youth total (% of people ages 15-24)"]  = 99.744
ch_missing.loc[4,"Literacy rate, youth total (% of people ages 15-24)"]  = 99.89
ch_missing.loc[10,"Literacy rate, youth total (% of people ages 15-24)"] = 99.2
ch_missing.loc[11,"Literacy rate, youth total (% of people ages 15-24)"] = 99
ch_missing.loc[12,"Literacy rate, youth total (% of people ages 15-24)"] = 98.66
ch_missing.loc[13,"Literacy rate, youth total (% of people ages 15-24)"] = 67.9
ch_missing.loc[14,"Literacy rate, youth total (% of people ages 15-24)"] = 99.123
ch_missing.loc[16,"Literacy rate, youth total (% of people ages 15-24)"] = 99.45
ch_missing.loc[18,"Literacy rate, youth total (% of people ages 15-24)"] = 96.282

ch_missing.loc[0,"Population, female"]  = 28366
ch_missing.loc[6,"Population, female"]  = 29784
ch_missing.loc[8,"Population, female"]  = 31675
ch_missing.loc[9,"Population, female"]  = 6541
ch_missing.loc[12,"Population, female"] = 9527
ch_missing.loc[17,"Population, female"] = 5662

ch_missing.loc[0,"Population, male"]  = 27254
ch_missing.loc[6,"Population, male"]  = 28274
ch_missing.loc[8,"Population, male"]  = 24887
ch_missing.loc[9,"Population, male"]  = 6335
ch_missing.loc[12,"Population, male"] = 8281
ch_missing.loc[17,"Population, male"] = 5708

ch_missing.loc[9,"Rural population (% of total population)"] = 0

ch_missing.loc[0,"Tax revenue (% of GDP)"]  = 37.8
ch_missing.loc[3,"Tax revenue (% of GDP)"]  = 39.4
ch_missing.loc[4,"Tax revenue (% of GDP)"]  = 21.4
ch_missing.loc[8,"Tax revenue (% of GDP)"]  = 20
ch_missing.loc[10,"Tax revenue (% of GDP)"] = 20.4
ch_missing.loc[17,"Tax revenue (% of GDP)"] = 15.204

ch_missing.to_excel('Cliffhanger_data_columns_missing_values.xlsx')

#---------------------Drop colums with more than 40% missing values-----------
ch_sec_drop = ch_missing.drop(["Agriculture, forestry, and fishing, value added (% of GDP)"], axis=1)
ch_sec_drop = ch_sec_drop.drop(["Armed forces personnel (% of total labor force)"], axis=1)
ch_sec_drop = ch_sec_drop.drop(["GINI index (World Bank estimate)"], axis=1)
ch_sec_drop = ch_sec_drop.drop(["Government expenditure on education, total (% of government expenditure)"], axis=1)
ch_sec_drop = ch_sec_drop.drop(["Industry (including construction), value added (% of GDP)"], axis=1)
ch_sec_drop = ch_sec_drop.drop(["Literacy rate, adult total (% of people ages 15 and above)"], axis=1)
ch_sec_drop = ch_sec_drop.drop(["Literacy rate, youth total (% of people ages 15-24)"], axis=1)
ch_sec_drop = ch_sec_drop.drop(["Military expenditure (% of GDP)"], axis=1)
ch_sec_drop = ch_sec_drop.drop(["Population in the largest city (% of urban population)"], axis=1)
ch_sec_drop = ch_sec_drop.drop(["Prevalence of HIV, total (% of population ages 15-49)"], axis=1)
ch_sec_drop = ch_sec_drop.drop(["Prevalence of undernourishment (% of population)"], axis=1)
ch_sec_drop = ch_sec_drop.drop(["Services, value added (% of GDP)"], axis=1)
ch_sec_drop = ch_sec_drop.drop(["Literacy rate, youth total (% of people ages 15 and above)"], axis=1)

# ch_sec_drop.to_excel('Cliffhanger_data_columns_missing_values_sec_drop.xlsx')

#-------------------------------Imputing Values-------------------------------

# American Samoa : Mean of other countires in the same income group
ch_impute = ch_sec_drop

ch_impute.loc[0,"Access to electricity (% of population)"] = 97.51
ch_impute.loc[0,"Access to electricity, rural (% of rural population)"] = 96.04
ch_impute.loc[0,"Access to electricity, urban (% of urban population)"] = 99.02
ch_impute.loc[0,"Adolescent fertility rate (births per 1,000 women ages 15-19)"] = 29.30
ch_impute.loc[0,"Birth rate, crude (per 1,000 people)"] = 22.79
ch_impute.loc[0,"Employment in agriculture (% of total employment) (modeled ILO estimate)"] = 25.21
ch_impute.loc[0,"Employment in industry (% of total employment) (modeled ILO estimate)"] = 19.17
ch_impute.loc[0,"Employment in services (% of total employment) (modeled ILO estimate)"] = 55.62
ch_impute.loc[0,"Fertility rate, total (births per woman)"] = 3.44
ch_impute.loc[0,"Life expectancy at birth, total (years)"] = 70.33
ch_impute.loc[0,"Mobile cellular subscriptions (per 100 people)"] = 79.96
ch_impute.loc[0,"Population ages 0-14 (% of total population)"] = 34.66
ch_impute.loc[0,"Population ages 15-64 (% of total population)"] = 60.03
ch_impute.loc[0,"Population ages 65 and above (% of total population)"] = 5.32

ADF_median = ch_impute['Adolescent fertility rate (births per 1,000 women ages 15-19)'].median()
ch_impute['Adolescent fertility rate (births per 1,000 women ages 15-19)'] = ch_impute['Adolescent fertility rate (births per 1,000 women ages 15-19)'].fillna(ADF_median).round(2)

EIA_median = ch_impute['Employment in agriculture (% of total employment) (modeled ILO estimate)'].median()
ch_impute['Employment in agriculture (% of total employment) (modeled ILO estimate)'] = ch_impute['Employment in agriculture (% of total employment) (modeled ILO estimate)'].fillna(EIA_median).round(2)

EII_median = ch_impute['Employment in industry (% of total employment) (modeled ILO estimate)'].median()
ch_impute['Employment in industry (% of total employment) (modeled ILO estimate)'] = ch_impute['Employment in industry (% of total employment) (modeled ILO estimate)'].fillna(EII_median).round(2)

EIS_median = ch_impute['Employment in services (% of total employment) (modeled ILO estimate)'].median()
ch_impute['Employment in services (% of total employment) (modeled ILO estimate)'] = ch_impute['Employment in services (% of total employment) (modeled ILO estimate)'].fillna(EIS_median).round(2)

FRT_median = ch_impute['Fertility rate, total (births per woman)'].median()
ch_impute['Fertility rate, total (births per woman)'] = ch_impute['Fertility rate, total (births per woman)'].fillna(FRT_median).round(2)

LEB_median = ch_impute['Life expectancy at birth, total (years)'].median()
ch_impute['Life expectancy at birth, total (years)'] = ch_impute['Life expectancy at birth, total (years)'].fillna(LEB_median).round(2)

MT_median = ch_impute['Merchandise trade (% of GDP)'].median()
ch_impute['Merchandise trade (% of GDP)'] = ch_impute['Merchandise trade (% of GDP)'].fillna(MT_median).round(2)

MS_median = ch_impute['Mobile cellular subscriptions (per 100 people)'].median()
ch_impute['Mobile cellular subscriptions (per 100 people)'] = ch_impute['Mobile cellular subscriptions (per 100 people)'].fillna(MS_median).round(2)

PAT_median = ch_impute['Population ages 0-14 (% of total population)'].median()
ch_impute['Population ages 0-14 (% of total population)'] = ch_impute['Population ages 0-14 (% of total population)'].fillna(PAT_median).round(2)

PA15_median = ch_impute['Population ages 15-64 (% of total population)'].median()
ch_impute['Population ages 15-64 (% of total population)'] = ch_impute['Population ages 15-64 (% of total population)'].fillna(PA15_median).round(2)

PA65_median = ch_impute['Population ages 65 and above (% of total population)'].median()
ch_impute['Population ages 65 and above (% of total population)'] = ch_impute['Population ages 65 and above (% of total population)'].fillna(PA65_median).round(2)

ch_impute.to_excel('Final_Cliffhanger_data_columns_missing_values_sec_drop_impute.xlsx')

ch_rename = ch_impute
#-----------------------------imputing completed------------------------------

#--------------------------------Rename Columns-------------------------------

# file  = 'Cliffhanger_data_columns_missing_values_sec_drop_impute.xlsx'
# ch_rename    = pd.read_excel(file)

# ch_rename.rename(columns = {'Unnamed: 0.1':'Index from the dataset',
#                         'Access to electricity (% of population)' : 'Acc_Elec %',
#                         'Access to electricity, rural (% of rural population)': 'Acc_Elec_Rur %',
#                         'Access to electricity, urban (% of urban population)': 'Acc_Elec_urb %',
#                         'Adolescent fertility rate (births per 1,000 women ages 15-19)' : 'Adol_Fert_Rate',
#                         'Age dependency ratio (% of working-age population)': 'Age_Dep_rat %',
#                         'Age dependency ratio, old (% of working-age population)': 'Age_Dep_Rat_old %',
#                         'Age dependency ratio, young (% of working-age population)': 'Age_Dep_Rat_young %',
#                         'Birth rate, crude (per 1,000 people)' : 'Birth_Rate',
#                         'Death rate, crude (per 1,000 people)': 'Death_rate',
#                         'Death rate, crude (per 1,000 people)': 'Death_rate',
#                         'Employment in agriculture (% of total employment) (modeled ILO estimate)': 'Emp_agric %',  
#                         'Employment in industry (% of total employment) (modeled ILO estimate)' : 'Emp_indust %',
#                         'Employment in services (% of total employment) (modeled ILO estimate)': 'Emp_Service %',
#                         'Fertility rate, total (births per woman)': 'Fert_Rate',
#                         'GDP (current US$)': 'Gdp_Us$',
#                         'GDP growth (annual %)': 'Gdp_Growth',
#                         'Life expectancy at birth, total (years)': 'Life_expect',
#                         'Merchandise trade (% of GDP)' : 'Merch_Trade %',
#                         'Mobile cellular subscriptions (per 100 people)' : 'Mob_Cell_Subsc',
#                         'Number of people pushed below the $3.10 ($ 2011 PPP) poverty line by out-of-pocket health care expenditure': 'People_Below_$3.10',
#                         'Population ages 0-14 (% of total population)': 'Population_0-14 %',
#                         'Population ages 15-64 (% of total population)' : 'Population_15-64 %',
#                         'Population ages 65 and above (% of total population)': 'Population_above65 %',
#                         'Population density (people per sq. km of land area)': 'Population_density',
#                         'Population growth (annual %)': 'Population_Growth %',
#                         'Population living in slums (% of urban population)': 'Population_Slums %',
#                         'Population, female': 'Population_Female',
#                         'Population, male': 'Population_Male',
#                         'Population, total':'Population',
#                         'Surface area (sq. km)' : 'Surface_Area',
#                         'Tax revenue (% of GDP)' : 'Tax_Rev %',
#                         'Urban population (% of total population)' : 'Urban_Population',
#                         'Urban population growth (annual %)' : 'Urban_Population_Growth'
#                         })

#-----------------------------Renaming completed------------------------------

# # ---------------------To create flags for missing values---------------------
# ch_test = ch_impute

# for col in ch_test:
#     if ch_test[col].isnull().astype(int).sum() > 0:
#         ch_test['m_' + col] = ch_test[col].isnull().astype(int)

# ch_test.to_excel('test_Cliffhanger_data_columns_missing_values.xlsx')

# #-----------------------------------------------------------------------------

# # ------------------To check for unaccounted missing values-------------------
# a = ch_test.isnull().sum().sum()

# print(a,)

# if a == b:
#     print('\nAll missing values accounted for.')
# else:
#     print('\nSome missing values may be unaccounted for, please audit.')

# #-----------------------------------------------------------------------------

# %%
#-----------------------------Correlation Heatmap-----------------------------
ch_corr = ch_rename.corr()
ch
sns.heatmap(data       = ch_corr,
            cmap       = 'Blues',
            square     = True,
            annot      = False,
            linecolor  = 'black',
            linewidths = 0.5)


bottom, top = plt.ylim() # discover the values for bottom and top
bottom += 0.5            # add 0.5 to the bottom
top -= 0.5               # subtract 0.5 from the top
plt.ylim(bottom, top)    # update the ylim(bottom, top) values

plt.savefig('Australia Oceania')
plt.show()
#-----------------------------------------------------------------------------

# %%
#------------------------------------Plots------------------------------------

#********employment variable
service=ch_rename['Employment in services (% of total employment) (modeled ILO estimate)']
agriculture=ch_rename['Employment in agriculture (% of total employment) (modeled ILO estimate)']
industry=ch_rename['Employment in industry (% of total employment) (modeled ILO estimate)']
country=ch_rename['Country Name']
employment=['service','agriculture','industry']

# ******* other variables
birth =ch_rename['Birth rate, crude (per 1,000 people)']
fertility=ch_rename['Fertility rate, total (births per woman)']
age_dep=ch_rename['Age dependency ratio, young (% of working-age population)']
electricity=ch_rename['Access to electricity (% of population)']
population1=ch_rename['Population ages 15-64 (% of total population)']
population2=ch_rename['Population ages 0-14 (% of total population)']
gdp=ch_rename['GDP (current US$)']

# employment visualization
plt.figure(figsize=(10,6))

plt.bar(country,service)
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('% of Employment')


plt.bar(country,agriculture)
plt.xticks(rotation=90)
plt.xlabel('Country')


plt.bar(country,industry)
plt.xticks(rotation=90)
plt.xlabel('Country')

plt.legend(employment,loc=0)


# plt.savefig('employment.png')
        
plt.figure(figsize=(10,6))

plt.bar(country,service)
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Employment in services (% of total employment) (modeled ILO estimate)')

# plt.savefig('service.png')
        
plt.figure(figsize=(10,6))

plt.bar(country,agriculture)
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Employment in agriculture (% of total employment) (modeled ILO estimate)')

# plt.savefig('agriculture.png')

plt.figure(figsize=(10,6))

plt.bar(country,industry)
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Employment in industry (% of total employment) (modeled ILO estimate)')


# plt.savefig('indusrtry.png')  
        
        # age dependency ratio visualization
plt.figure(figsize=(10,6))

plt.bar(country,age_dep)
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Age dependency ratio, young (% of working-age population) ')

# plt.savefig('age dependency.png')
        
        # fertility visualisation
plt.figure(figsize=(10,6))

plt.bar(country,fertility)
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Fertility rate, total (births per woman)')

# plt.savefig('fertility.png')
        
        # birth rate visualization
plt.figure(figsize=(10,6))

plt.bar(country,birth)
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Birth rate, crude (per 1,000 people)')

# plt.savefig('birth rate.png')
        
        # Acces to electricity visualization
plt.figure(figsize=(10,6))

plt.bar(country,electricity)
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Access to electricity (% of population)')

# plt.savefig('accces electricity.png')

        #  Population ages 15-64
plt.figure(figsize=(10,6))

plt.bar(country,population1)
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Population ages 15-64 (% of total population)')

# plt.savefig('population 15-64.png')
        
        #  Population ages 0-14
plt.figure(figsize=(10,6))

plt.bar(country,population2)
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Population ages 0-14 (% of total population)')

# plt.savefig('population 0-14.png')
        
#  GDP visualization
plt.figure(figsize=(10,6))

plt.bar(country,gdp)
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('GDP (current US$)')

# plt.savefig('gdp.png')
        
#  Gdp Boxplot
ch_rename.boxplot(column = ['GDP (current US$)'])

# displaying the plot
plt.show()
# plt.savefig('gdp1.png')

#  Gdp Boxplot
ch_rename.boxplot(column = ['GDP (current US$)'])

# displaying the plot
plt.show()
# plt.savefig('gdp1.png')

ch_rename.boxplot(column = ['GDP (current US$)'])

# displaying the plot
plt.show()
# plt.savefig('birth rate')

ch_rename.boxplot(column = ['Birth rate, crude (per 1,000 people)'])

# displaying the plot
plt.show()
# plt.savefig('birth rate')

ch_rename.boxplot(column = ['Fertility rate, total (births per woman)'])

# displaying the plot
plt.show()
# plt.savefig('birth rate')

#-----------------------------------------------------------------------------
